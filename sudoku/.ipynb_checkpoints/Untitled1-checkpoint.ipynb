# %%
import cv2
import numpy as np
from PIL import Image
sud = cv2.cvtColor(cv2.UMat('sudokubig.jpg'),cv2.COLOR_BGR2Luv)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5683cf45e712> in <module>
#       2 import numpy as np
#       3 from PIL import Image
# ----> 4 sud = cv2.cvtColor(cv2.UMat('sudokubig.jpg'),cv2.COLOR_BGR2Luv)
#
# TypeError: UMat() missing required argument 'ranges' (pos 2)

# %%
pil_image = Image.open('sudokubig.jpg').convert('RGB') 
open_cv_image = np.array(pil_image)

# %%
sud = cv2.cvtColor(open_cv_image,cv2.COLOR_BGR2Luv)
